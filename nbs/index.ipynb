# %%
#| hide
from splif_sim.core import *

# %% [markdown]
# # splif-sim
#
# > Interaction fingerprints for ligand binding mode identification

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install splif_sim in Development mode

# %% [markdown]
# ```sh
# # make sure splif_sim package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to splif_sim
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/roshkjr/splif-sim.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c roshkjr splif_sim
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install splif_sim
# ```
#
#
# [repo]: https://github.com/roshkjr/splif-sim
# [docs]: https://roshkjr.github.io/splif-sim/
# [pypi]: https://pypi.org/project/splif-sim/
# [conda]: https://anaconda.org/roshkjr/splif-sim

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/roshkjr/splif-sim
# [docs]: https://roshkjr.github.io/splif-sim/
# [pypi]: https://pypi.org/project/splif-sim/
# [conda]: https://anaconda.org/roshkjr/splif-sim

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
